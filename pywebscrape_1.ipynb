# %%
from bs4 import BeautifulSoup
import urllib3.request,sys,time
import requests
import pandas as pd
import re

# %%
#url of the page that we want to Scarpe
#+str() is used to convert int datatype of the page no. and concatenate that to a URL for pagination purposes.
URL = 'https://www.japantimes.co.jp/'+str(page)
#Use the browser to get the URL. This is a suspicious command that might blow up.
page = requests.get('https://www.japantimes.co.jp/')

# %%
page.status_code
# Out:
# 200

# %%
page.text
# Out:
# '<!doctype html>\n<html class="no-js" lang="en-US" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">\n<head>\n<meta charset="UTF-8">\n<title>The Japan Times - News on Japan, Business News, Opinion, Sports, Entertainment and More</title>\n<link rel="pingback" href="https://www.japantimes.co.jp/xmlrpc.php">\n<meta name="verify-v1" content="+h35BdFddo/f1upXot92yGKSB4d5EuWWGbARz9SJE6A=">\n<meta property="twitter:account_id" content="7424642">\n<meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1">\n<meta name="HandheldFriendly" content="true">\n<link rel="alternate" type="application/rss+xml" href="https://www.japantimes.co.jp/feed/topstories/" title="The Japan Times RSS Feed - Today\'s Top Stories"><link rel="shortcut icon" href="https://www.japantimes.co.jp/wp-content/themes/jt_theme/library/img/japantimes-favicon.ico">\n<link rel="apple-touch-icon" href="https://www.japantimes.co.jp/wp-content/themes/jt_theme/library/img/apple-touch-icon-72px.png">\n<link rel="apple-touch-icon" sizes="72x72" href="https://www.japantimes.co.jp/wp-content/themes/jt_theme/library/img/apple-touch-icon-72px.png">\n<link rel="apple-touch-icon" sizes="114x114" href="https://www.japantimes.co.jp/wp-content/themes/jt_theme/library/img/apple-touch-icon-144px.png">\n<meta name="apple-mobile-web-app-title" content="Japan Times">\n<meta name="robots" content="noarchive">\n<meta name="cXenseParse:pageclass" content="frontpage">\n<meta name="thumbnail" content="https://www.japantimes.co.jp/wp-content/themes/jt_theme/library/img/japantimes-logo_square.png">\n<link rel="stylesheet" href="https://www.japantimes.co.jp/wp-content/plugins/jt_olympic_schedule/styles.css?1646168347" type="text/css" id="olympic_schedule">\n<script src="https://www.japantimes.co.jp/wp-content/plugins/jt_piano_integration/js/hmac-sha1-3.1.2.js"></script><script src="https://www.japantimes.co.jp/wp-content/plugins/jt_piano_integration/js/md5.js"></script><!-- Piano -->\n<script type="text/javascript">\n( function ( src ) {\n    var a = document.createElement( \'script\' );\n    a.type = \'text/javascript\';\n    a.async = true;\n    a.src = src;\n    var b = document.getElementsByTagName(\'script\')[0];\n    b.parentNode.insertBefore( a, b )\n} )( "//experience-ap.piano.io/xbuilder/experience/load?aid=bWOWSdhXpj" );\n</script>\n<!-- End Piano -->\n\n<!-- This site is optimized with the Yoast SEO Premium plugin v3.5.2 - https://yoast.com/wordpress/plugins/seo/ -->\n<meta name="description" content="Latest news and features from Japan: business, politics, commentary culture, life &amp; style, entertainment and sports"/>\n<meta name="robots" content="noodp"/>\n<meta name="keywords" content="Japan news, breaking news, Japan"/>\n<link rel="canonical" href="https://www.japantimes.co.jp/" />\n<meta property="og:locale" content="en_US" />\n<meta property="og:type" content="website" />\n<meta property="og:title" content="The Japan Times" />\n<meta property="og:description" content="News on Japan, Business News, Opinion, Sports, Entertainment and More" />\n<meta property="og:url" content="https://www.japantimes.co.jp/" />\n<meta property="og:site_name" content="The Japan Times" />\n<meta property="fb:app_id" content="119406745111" />\n<meta property="og:image" content="https://cdn-japantimes.com/wp-content/uploads/2017/04/jt-sns.png" />\n<script type=\'application/ld+json\'>{"@context":"http:\\/\\/schema.org","@type":"WebSite","@id":"#website","url":"https:\\/\\/www.japantimes.co.jp\\/","name":"The Japan Times","potentialAction":{"@type":"SearchAction","target":"https:\\/\\/www.japantimes.co.jp\\/?s={search_term_string}","query-input":"required name=search_term_string"}}</script>\n<script type=\'application/ld+json\'>{"@context":"http:\\/\\/schema.org","@type":"Organization","url":"https:\\/\\/www.japantimes.co.jp\\/","sameAs":["https:\\/\\/www.facebook.com\\/thejapantimes","https:\\/\\/instagram.com\\/thejapantimes\\/","https:\\/\\/www.linkedin. ...

# %%
page.content
# Out:
# b'<!doctype html>\n<html class="no-js" lang="en-US" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">\n<head>\n<meta charset="UTF-8">\n<title>The Japan Times - News on Japan, Business News, Opinion, Sports, Entertainment and More</title>\n<link rel="pingback" href="https://www.japantimes.co.jp/xmlrpc.php">\n<meta name="verify-v1" content="+h35BdFddo/f1upXot92yGKSB4d5EuWWGbARz9SJE6A=">\n<meta property="twitter:account_id" content="7424642">\n<meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1">\n<meta name="HandheldFriendly" content="true">\n<link rel="alternate" type="application/rss+xml" href="https://www.japantimes.co.jp/feed/topstories/" title="The Japan Times RSS Feed - Today\'s Top Stories"><link rel="shortcut icon" href="https://www.japantimes.co.jp/wp-content/themes/jt_theme/library/img/japantimes-favicon.ico">\n<link rel="apple-touch-icon" href="https://www.japantimes.co.jp/wp-content/themes/jt_theme/library/img/apple-touch-icon-72px.png">\n<link rel="apple-touch-icon" sizes="72x72" href="https://www.japantimes.co.jp/wp-content/themes/jt_theme/library/img/apple-touch-icon-72px.png">\n<link rel="apple-touch-icon" sizes="114x114" href="https://www.japantimes.co.jp/wp-content/themes/jt_theme/library/img/apple-touch-icon-144px.png">\n<meta name="apple-mobile-web-app-title" content="Japan Times">\n<meta name="robots" content="noarchive">\n<meta name="cXenseParse:pageclass" content="frontpage">\n<meta name="thumbnail" content="https://www.japantimes.co.jp/wp-content/themes/jt_theme/library/img/japantimes-logo_square.png">\n<link rel="stylesheet" href="https://www.japantimes.co.jp/wp-content/plugins/jt_olympic_schedule/styles.css?1646168347" type="text/css" id="olympic_schedule">\n<script src="https://www.japantimes.co.jp/wp-content/plugins/jt_piano_integration/js/hmac-sha1-3.1.2.js"></script><script src="https://www.japantimes.co.jp/wp-content/plugins/jt_piano_integration/js/md5.js"></script><!-- Piano -->\n<script type="text/javascript">\n( function ( src ) {\n    var a = document.createElement( \'script\' );\n    a.type = \'text/javascript\';\n    a.async = true;\n    a.src = src;\n    var b = document.getElementsByTagName(\'script\')[0];\n    b.parentNode.insertBefore( a, b )\n} )( "//experience-ap.piano.io/xbuilder/experience/load?aid=bWOWSdhXpj" );\n</script>\n<!-- End Piano -->\n\n<!-- This site is optimized with the Yoast SEO Premium plugin v3.5.2 - https://yoast.com/wordpress/plugins/seo/ -->\n<meta name="description" content="Latest news and features from Japan: business, politics, commentary culture, life &amp; style, entertainment and sports"/>\n<meta name="robots" content="noodp"/>\n<meta name="keywords" content="Japan news, breaking news, Japan"/>\n<link rel="canonical" href="https://www.japantimes.co.jp/" />\n<meta property="og:locale" content="en_US" />\n<meta property="og:type" content="website" />\n<meta property="og:title" content="The Japan Times" />\n<meta property="og:description" content="News on Japan, Business News, Opinion, Sports, Entertainment and More" />\n<meta property="og:url" content="https://www.japantimes.co.jp/" />\n<meta property="og:site_name" content="The Japan Times" />\n<meta property="fb:app_id" content="119406745111" />\n<meta property="og:image" content="https://cdn-japantimes.com/wp-content/uploads/2017/04/jt-sns.png" />\n<script type=\'application/ld+json\'>{"@context":"http:\\/\\/schema.org","@type":"WebSite","@id":"#website","url":"https:\\/\\/www.japantimes.co.jp\\/","name":"The Japan Times","potentialAction":{"@type":"SearchAction","target":"https:\\/\\/www.japantimes.co.jp\\/?s={search_term_string}","query-input":"required name=search_term_string"}}</script>\n<script type=\'application/ld+json\'>{"@context":"http:\\/\\/schema.org","@type":"Organization","url":"https:\\/\\/www.japantimes.co.jp\\/","sameAs":["https:\\/\\/www.facebook.com\\/thejapantimes","https:\\/\\/instagram.com\\/thejapantimes\\/","https:\\/\\/www.linkedin ...

# %%
print (page.headers.get("content-type", "unknown"))
# Out:
# text/html; charset=UTF-8

# %% [markdown]
# Delaying request time

# %%
time.sleep(2)

# %% [markdown]
# Extracting Content

# %%
print(re.findall(r'\$[0-9,.]+', page.text))
# Out:
# ['$.', '$17', '$.']

# %%
soup = BeautifulSoup(page.text, "html.parser")

# %%
links=soup.find_all('p',attrs={'class':'article-title'})

# %%
print(len(links))
# Out:
# 26

# %% [markdown]
# finding elements and attributes

# %%
links = soup.find_all("p")

# %%
Statement = j.find("div",attrs={'class':'article-title'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13480/3311212820.py in <module>
# ----> 1 Statement = j.find("div",attrs={'class':'article-title'})
#
# NameError: name 'j' is not defined
